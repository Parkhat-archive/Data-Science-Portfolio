# %%
# Mobile Net Model

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()

# %%
def prepare_image(file):
    img_path = r"C:\Users\Mubarak\Downloads\MobileNetSample"
    img = image.load_img(img_path + "\\" + file, target_size=(224,224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims= np.expand_dims(img_array, axis=0)
    return tf.keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
from IPython.display import Image
Image(filename= r"C:\Users\Mubarak\Downloads\MobileNetSample\7.jpg", width=300, height=200)

# %%
preprocessed_image = prepare_image("7.jpg")
predictions= mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n07920052', 'espresso', 0.93318045),
#   ('n07930864', 'cup', 0.045559827),
#   ('n03063599', 'coffee_mug', 0.014806339),
#   ('n03733805', 'measuring_cup', 0.0014241758),
#   ('n03063689', 'coffeepot', 0.001277328)]]

# %%
from IPython.display import Image
Image(filename= r"C:\Users\Mubarak\Downloads\MobileNetSample\1.jpeg", width=300, height=200)

# %%
preprocessed_image = prepare_image("1.jpeg")
predictions= mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n02119789', 'kit_fox', 0.1708058),
#   ('n02443484', 'black-footed_ferret', 0.13684325),
#   ('n02443114', 'polecat', 0.12133286),
#   ('n02132136', 'brown_bear', 0.108340845),
#   ('n02119022', 'red_fox', 0.08582775)]]

# %%
from IPython.display import Image
Image(filename= r"C:\Users\Mubarak\Downloads\MobileNetSample\8.jpg", width=300, height=200)

# %%
preprocessed_image = prepare_image("8.jpg")
predictions= mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n07715103', 'cauliflower', 0.8392182),
#   ('n07745940', 'strawberry', 0.06590834),
#   ('n07760859', 'custard_apple', 0.020129645),
#   ('n07714571', 'head_cabbage', 0.01983375),
#   ('n07720875', 'bell_pepper', 0.009264694)]]
